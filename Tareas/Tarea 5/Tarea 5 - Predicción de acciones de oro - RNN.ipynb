# %% [markdown]
# <table width='100%'>
# <tr>
# <td style='background-color:white'>
#     <p align="left">
#     Departamento de estadística<br>
#         <b>Inteligencia Artificial</b><br>
#     Semestre 2023-I
#     </p>
# </td>
#     <td style='background-color:white'>
#         <p align="right">
#         <img src="logo.jpg" width="200">
#     </td>
# </tr>
# </table>
#
# <br>
# <center>
#     <h1>Predicción multipaso de serie multivariada: Acciones del Oro</h1>
# </center>
# <br>

# %%
# Librerías estándar para manejo de datos/mates
import numpy as np
import pandas as pd

# Suscribirse a la API de Yahoo
import yfinance as yf

# Gráficos
import matplotlib.pyplot as plt
import matplotlib as mpl

# Configurar tamaño de gráficos
mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# Escalador
from sklearn.preprocessing import MinMaxScaler

# Keras Network @ https://www.tensorflow.org/guide/keras/rnn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Reproducibilidad
import random
random.seed(2505)
tf.random.set_seed(13)

# Funciones auxiliares del cuaderno del profe
import auxiliares as aux

# %%
print('version de tf: ', tf.__version__)
# Out:
# version de tf:  2.9.1

# %% [markdown]
# # Sobre la serie a utilizar
#
# Debido a la naturaleza multifactorial y no lineal del mercado del oro, es difícil predecir el precio del oro. El precio del oro se ve afectado por muchos factores externos, como el entorno del mercado, las crisis económicas, los aumentos del precio del petróleo, las ventajas fiscales y las tasas de interés. Por lo tanto, los modelos multivariados pueden predecir mejor el precio del oro que los modelos univariados.

# %% [markdown]
# # Cargar y limpiar datos

# %%
# Datos diarios de oro
stock = 'GC=f'

# Rango de fechas considerado
start_date = '2015-12-20' # Fecha más estable
end_date = '2023-09-04'

# Extraer datos de la API de Yahoo
gold = yf.download(stock, start = start_date, end = end_date)  # Por defecto lo toma hasta hoy

# Reordenar columnas para poner de última la variable objetivo
gold = gold[['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold
# Out:
#                    High          Low         Open        Close  Volume  \
# Date
# 2015-12-21  1081.900024  1070.199951  1070.199951  1081.900024      26
# 2015-12-22  1078.599976  1073.800049  1078.599976  1074.800049     106
# 2015-12-23  1074.800049  1069.400024  1074.500000  1069.400024     202
# 2015-12-24  1077.800049  1073.500000  1074.300049  1077.199951      24
# 2015-12-28  1098.800049  1070.500000  1077.900024  1070.500000     361
# ...                 ...          ...          ...          ...     ...
# 2023-05-30  1962.599976  1931.000000  1942.699951  1958.000000   37838
# 2023-05-31  1973.000000  1953.000000  1958.199951  1963.900024    5959
# 2023-06-01  1983.000000  1954.300049  1963.199951  1978.000000     750
# 2023-06-02  1982.500000  1947.400024  1977.099976  1952.400024     750
# 2023-06-04  1966.000000  1960.500000  1947.500000  1961.599976   16676
#
#               Adj Close
# Date
# 2015-12-21  1081.900024
# 2015-12-22  1074.800049
# 2015-12-23  1069.400024
# 2015-12-24  1077.199951
# 2015-12-28  1070.500000
# ...                 ...
# 2023-05-30  1958.000000
# 2023-05-31  1963.900024
# 2023-06-01  1978.000000
# 2023-06-02  1952.400024
# 2023-06-04  1961.599976
#
# [1875 rows x 6 columns]

# %%
gold.plot(subplots=True, rot=45, xlabel='Año')
plt.show()

# %% [markdown]
# ## Escalar datos

# %%
x = gold.values # Retorna un array de numpy

# Escalador 
min_max_scaler = MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
gold_np_scaled = pd.DataFrame(x_scaled)

# %% [markdown]
# ## Ajustar los datos

# %%
# Necesitamos que la muestra esté en la forma (muestra, tamaño de ventana, número de canales)

samples = 10 # Número de muestras en el pasado (ventana)
steps = 1 # Número de pasos a predecir en el futuro
X = [] # X array
Y = [] # Y array

for i in range(gold_np_scaled.shape[0] - samples):
    X.append(gold_np_scaled.iloc[i:i+samples, 0:5].values) # Muestras independientes
    Y.append(gold_np_scaled.iloc[i+samples, 5:].values) # Muestra dependiente (índice de Adj Close)
print('Datos para entrenamiento: Su tamaño es',len(X[0:1][0]),': ', X[0:1])
print('Dato objetivo: Su tamaño es', len(Y[0:1]),': ', Y[0:1])
# Out:
# Datos para entrenamiento: Su tamaño es 10 :  [array([[1.97029945e-02, 1.19204801e-02, 8.36939210e-03, 2.19891550e-02,
#         6.72992799e-05],
#        [1.64356194e-02, 1.55884349e-02, 1.68397196e-02, 1.48275902e-02,
#         2.74373987e-04],
#        [1.26733157e-02, 1.11054757e-02, 1.27054297e-02, 9.38072282e-03,
#         5.22863636e-04],
#        [1.56436127e-02, 1.52827305e-02, 1.25038051e-02, 1.72483106e-02,
#         6.21224122e-05],
#        [3.64356919e-02, 1.22261844e-02, 1.61339103e-02, 1.04902402e-02,
#         9.34424617e-04],
#        [1.75247041e-02, 1.93581253e-02, 1.73439043e-02, 1.75509623e-02,
#         6.52285328e-04],
#        [8.11876354e-03, 1.22256869e-03, 6.75602569e-03, 0.00000000e+00,
#         1.83778803e-04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.01808793e-04,
#         2.58843384e-05],
#        [2.02970297e-02, 4.78853915e-03, 1.51255409e-03, 1.51301187e-02,
#         3.70146039e-04],
#        [1.93069307e-02, 1.71167079e-02, 1.38146114e-02, 1.84587940e-02,
#         2.12251575e-04]])]
# Dato objetivo: Su tamaño es 1 :  [array([0.0320759])]

# %%
# Debemos hacer un reshape de los inputs para que el modelo los acepte
X = np.array(X)
Y = np.array(Y)
print('Dimensión de X', X.shape, '\nDimensión de Y', Y.shape)
# Out:
# Dimensión de X (1865, 10, 5)
# Dimensión de Y (1865, 1)

# %% [markdown]
# ## Conjunto de entrenamiento y prueba

# %%
threshold = round(0.9 * X.shape[0])  # "Training split" (90-10)

# Conjunto de entrenamiento y de prueba
trainX, trainY = X[:threshold], Y[:threshold]
testX, testY =  X[threshold:], Y[threshold:]

# Ver las dimensiones
print('Training Length',trainX.shape, trainY.shape,'\nTesting Length:',testX.shape, testY.shape)
# Out:
# Training Length (1678, 10, 5) (1678, 1)
# Testing Length: (187, 10, 5) (187, 1)

# %% [markdown]
# # Modelo de predicción un paso adelante

# %% [markdown]
# ### 1. RNN

# %%
# Construiremos la RNN a través de Sequential
model_RNN = keras.Sequential()

# Añadimos una capa tipo RNN con 30 nodos
model_RNN.add(layers.SimpleRNN(30,
                           activation = 'tanh',
                           use_bias=True,
                           input_shape=(trainX.shape[1], trainX.shape[2])))

# Añadimos una capa "dropout" que penalice modelos más complejos -> prevenga overfitting y generalice mejor
model_RNN.add(layers.Dropout(rate=0.2))  # 20% de las neuronas se apagan

# Añadir un perceptrón con un nodo de salida (porque estamos haciendo una regresión)
model_RNN.add(layers.Dense(1))

# La función de pérdida va a ser el MSE, minimizada a través del optimizador adam
model_RNN.compile(loss='mean_squared_error', optimizer = 'adam')

# Ver la arquitectura del modelo
model_RNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 30)                1080
#
#  dropout (Dropout)           (None, 30)                0
#
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 1,111
# Trainable params: 1,111
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2. LSTM

# %%
# Construir un modelo LSTM 
model_LSTM = keras.Sequential()

# Capa LSTM con 32 nodos
model_LSTM.add(layers.LSTM(32,
                           activation = "tanh",
                           recurrent_activation = "sigmoid",
                           input_shape=(trainX.shape[1], trainX.shape[2])
                          ))

# Añadimos una capa "dropout" que penalice modelos más complejos -> prevenga overfitting y generalice mejor
model_LSTM.add(layers.Dropout(rate=0.2))


# Añadir un perceptrón con un nodo de salida (porque estamos haciendo una regresión)
model_LSTM.add(layers.Dense(1))

# Evaluar la función de pérdida MSE usando el optimizador "adam"
model_LSTM.compile(loss='mean_squared_error', optimizer = 'adam')

# Arquitectura
model_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4864
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenar modelos

# %%
# Ajustar los datos al modelo 1
history_RNN = model_RNN.fit(trainX,
                            trainY,
                            shuffle = False, # Para no perder la estructura de autocorrelación temporal
                            epochs=100,
                            batch_size=32,
                            validation_split=0.2,
                            verbose=1) # Ver el avance

# Ajustar los datos al modelo 2
history_LSTM = model_LSTM.fit(trainX,
                            trainY,
                            shuffle = False, # Para no perder la estructura de autocorrelación temporal
                            epochs=100,
                            batch_size=32,
                            validation_split=0.2,
                            verbose=1) # Ver el avance
# Out:
# Epoch 1/100
# 42/42 [==============================] - 2s 14ms/step - loss: 0.0294 - val_loss: 0.0028
# Epoch 2/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0056
# Epoch 3/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0034
# Epoch 4/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0019
# Epoch 5/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 6.7426e-04
# Epoch 6/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0011
# Epoch 7/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 8/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 9/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 10/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 11/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 12/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 13/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 14/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 15/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 16/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 17/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 18/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 19/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 20/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 6.2940e-04
# Epoch 21/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 3.9764e-04
# Epoch 22/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 5.7190e-04
# Epoch 23/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 5.0206e-04
# Epoch 24/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 4.0920e-04
# Epoch 25/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 3.8991e-04
# Epoch 26/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 6.0683e-04
# Epoch 27/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 3.9244e-04
# Epoch 28/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 5.6061e-04
# Epoch 29/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 5.5553e-04
# Epoch 30/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 4.6411e-04
# Epoch 31/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 6.7236e-04
# Epoch 32/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 7.5686e-04
# Epoch 33/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 7.3203e-04
# Epoch 34/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 8.0947e-04
# Epoch 35/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 36/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 37/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 38/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 40/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 41/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 6.2922e-04
# Epoch 42/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 43/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 8.2827e-04
# Epoch 44/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 8.1266e-04
# Epoch 45/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 8.5373e-04
# Epoch 46/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 47/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 48/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 49/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 50/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 51/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 6.8060e-04
# Epoch 52/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 4.7207e-04
# Epoch 53/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 4.4426e-04
# Epoch 54/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 6.5902e-04
# Epoch 55/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 56/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 4.5451e-04
# Epoch 57/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 6.9415e-04
# Epoch 58/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 59/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 60/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 5.4818e-04
# Epoch 61/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 62/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 63/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 64/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 65/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 5.9881e-04
# Epoch 66/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 6.2544e-04
# Epoch 67/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 9.5275e-04
# Epoch 68/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 3.9132e-04
# Epoch 69/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 70/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 3.9288e-04
# Epoch 71/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 5.9680e-04
# Epoch 72/100
# 42/42 [==============================] - 0s 5ms/step - loss: 9.6318e-04 - val_loss: 3.8336e-04
# Epoch 73/100
# 42/42 [==============================] - 0s 9ms/step - loss: 9.6655e-04 - val_loss: 4.0277e-04
# Epoch 74/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 5.1852e-04
# Epoch 75/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 4.9478e-04
# Epoch 76/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 77/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 78/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 4.0859e-04
# Epoch 79/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 4.5694e-04
# Epoch 80/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 7.0679e-04
# Epoch 81/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 8.2485e-04
# Epoch 82/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 83/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 5.9417e-04
# Epoch 84/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 6.5285e-04
# Epoch 85/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 4.9057e-04
# Epoch 86/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 6.5639e-04
# Epoch 87/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 3.3243e-04
# Epoch 88/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 7.4614e-04
# Epoch 89/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 7.8599e-04
# Epoch 90/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 4.7485e-04
# Epoch 91/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 4.5730e-04
# Epoch 92/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 6.4445e-04
# Epoch 93/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 8.2273e-04
# Epoch 94/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 95/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 6.7994e-04
# Epoch 96/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 97/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 8.7394e-04
# Epoch 98/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 99/100
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 4.6879e-04
# Epoch 100/100
# 42/42 [==============================] - 0s 8ms/step - loss: 9.7930e-04 - val_loss: 5.5318e-04
# Epoch 1/100
# 42/42 [==============================] - 7s 43ms/step - loss: 0.0109 - val_loss: 0.0023
# Epoch 2/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0081 - val_loss: 0.0093
# Epoch 3/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0091 - val_loss: 0.0086
# Epoch 4/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 5/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 6/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 7/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 9.2275e-04
# Epoch 8/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 8.7483e-04
# Epoch 9/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 10/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 7.7934e-04
# Epoch 11/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 12/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 13/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 14/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 15/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0058
# Epoch 16/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 17/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 18/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 7.9595e-04
# Epoch 19/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 20/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 21/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 7.9940e-04
# Epoch 22/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 23/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 24/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 5.4658e-04
# Epoch 25/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 26/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 27/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 28/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 29/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 8.1009e-04
# Epoch 30/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 31/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 32/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 33/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 34/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 35/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 9.6388e-04
# Epoch 36/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 8.4346e-04
# Epoch 37/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 6.1339e-04
# Epoch 38/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 39/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 40/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 41/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 42/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 43/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 44/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 45/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 6.2531e-04
# Epoch 46/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 47/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 5.9295e-04
# Epoch 48/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 49/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 5.0529e-04
# Epoch 50/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 7.4218e-04
# Epoch 51/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 52/100
# 42/42 [==============================] - 1s 16ms/step - loss: 0.0012 - val_loss: 4.7052e-04
# Epoch 53/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 4.7648e-04
# Epoch 54/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 8.7228e-04
# Epoch 55/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 9.9120e-04
# Epoch 56/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 7.3309e-04
# Epoch 57/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0015 - val_loss: 6.8868e-04
# Epoch 58/100
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 59/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0015 - val_loss: 8.0774e-04
# Epoch 60/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 7.5865e-04
# Epoch 61/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 8.3595e-04
# Epoch 62/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 8.1284e-04
# Epoch 63/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 5.6133e-04
# Epoch 64/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 6.9518e-04
# Epoch 65/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 6.7235e-04
# Epoch 66/100
# 42/42 [==============================] - 1s 15ms/step - loss: 9.4847e-04 - val_loss: 4.9736e-04
# Epoch 67/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 4.2198e-04
# Epoch 68/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 5.7171e-04
# Epoch 69/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 5.4034e-04
# Epoch 70/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 5.0638e-04
# Epoch 71/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0013 - val_loss: 8.0260e-04
# Epoch 72/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 73/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 74/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 75/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 76/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 4.9639e-04
# Epoch 77/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 6.3866e-04
# Epoch 78/100
# 42/42 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 79/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 4.8937e-04
# Epoch 80/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 5.4237e-04
# Epoch 81/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 82/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 9.3868e-04
# Epoch 83/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 8.7457e-04
# Epoch 84/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 4.2973e-04
# Epoch 85/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 9.3036e-04
# Epoch 86/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 3.7518e-04
# Epoch 87/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 4.5702e-04
# Epoch 88/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 5.4023e-04
# Epoch 89/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 6.0694e-04
# Epoch 90/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 8.3505e-04
# Epoch 91/100
# 42/42 [==============================] - 0s 11ms/step - loss: 8.7924e-04 - val_loss: 4.0462e-04
# Epoch 92/100
# 42/42 [==============================] - 0s 11ms/step - loss: 9.2376e-04 - val_loss: 5.6444e-04
# Epoch 93/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 9.8210e-04
# Epoch 94/100
# 42/42 [==============================] - 0s 11ms/step - loss: 9.9828e-04 - val_loss: 4.1991e-04
# Epoch 95/100
# 42/42 [==============================] - 0s 10ms/step - loss: 9.6964e-04 - val_loss: 4.4628e-04
# Epoch 96/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 3.6721e-04
# Epoch 97/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 98/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 7.5622e-04
# Epoch 99/100
# 42/42 [==============================] - 1s 12ms/step - loss: 9.9833e-04 - val_loss: 7.4166e-04
# Epoch 100/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0010 - val_loss: 5.1085e-04

# %% [markdown]
# ## Predicción (a un paso)

# %%
aux.plot_train_history(history_RNN,
                       'Función de pérdida\n(Modelo RNN a un paso)')

# %%
aux.plot_train_history(history_LSTM,
                       'Función de pérdida\n(Modelo LSTM a un paso)')

# %%
# Predicción un paso adelante
y_pred = model_RNN.predict(testX)
plt.plot(testY, label = 'Valor verdadero')
plt.plot(y_pred, label = 'Predicción')
plt.legend()
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
# Predicción un paso adelante
y_pred = model_LSTM.predict(testX)
plt.plot(testY, label = 'Valor verdadero')
plt.plot(y_pred, label = 'Predicción')
plt.legend()
# Out:
# 6/6 [==============================] - 1s 4ms/step

# %% [markdown]
# # Modelo de predicción múltiples pasos adelante

# %%
dataset = gold.values

TRAIN_SPLIT = int(len(dataset)*0.9 - 1)  # Threshold

data_mean = dataset[:TRAIN_SPLIT].mean(axis = 0)
data_std = dataset[:TRAIN_SPLIT].std(axis = 0)
dataset = (dataset - data_mean)/data_std

# %%
# Datos escalados en formato numpy array
dataset = x_scaled

past_history = 60  # Ventana de 60 observaciones pasadas (2 meses)
future_target = 5  # 5 pasos adelante
STEP = 1

x_train_multi, y_train_multi = aux.multivariate_data(dataset,       # Conjunto de entrada
                                                     dataset[:, 5], # Target
                                                     0,             # Índice inicial
                                                     TRAIN_SPLIT,   # Threshold
                                                     past_history,  # Cuántas observaciones pasadas
                                                     future_target, # Dentro de cuántas observaciones futuras pronosticar
                                                     STEP,          # Uno
                                                     single_step = True  # Sólo un valor
                                                    )
x_val_multi, y_val_multi = aux.multivariate_data(dataset,        # Todas las covariables
                                                 dataset[:, 5],  # Var objetivo
                                                 TRAIN_SPLIT,    # Empieza donde terminó training
                                                 None,           # Sigue hasta el final
                                                 past_history,
                                                 future_target,
                                                 STEP,
                                                 single_step = True)

# %%
print(x_train_multi.shape, "\n")

print ('Tamaño de una ventana de observaciones pasadas : {}'.format(x_train_multi[0].shape))
# Out:
# (1626, 60, 6)
#
# Tamaño de una ventana de observaciones pasadas : (60, 6)

# %%
BATCH_SIZE = 128
BUFFER_SIZE = 1000

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# Construiremos la RNN a través de Sequential
multi_step_model = keras.Sequential()

# Añadimos una capa tipo RNN con 30 nodos
multi_step_model.add(layers.SimpleRNN(30,
                                      activation = 'tanh',
                                      use_bias=True,
                                      input_shape= x_train_multi.shape[-2:]
                              ))

# Añadimos una capa "dropout" que penalice modelos más complejos -> prevenga overfitting y generalice mejor
multi_step_model.add(layers.Dropout(rate=0.2))  # 20% de las neuronas se apagan

# Añadir un perceptrón con un nodo por cada paso adelante (porque estamos haciendo una regresión)
multi_step_model.add(layers.Dense(1))

# La función de pérdida va a ser el MSE, minimizada a través del optimizador adam
multi_step_model.compile(loss='mean_squared_error', optimizer = 'adam')

# Ver la arquitectura del modelo
multi_step_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 30)                1110
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,141
# Trainable params: 1,141
# Non-trainable params: 0
# _________________________________________________________________

# %%
multi_step_history = multi_step_model.fit(train_data_multi,
                                          epochs = 500,
                                          steps_per_epoch = 40,
                                          validation_data = val_data_multi,
                                          validation_steps = 50)
# Out:
# Epoch 1/500
# 40/40 [==============================] - 3s 37ms/step - loss: 0.1479 - val_loss: 0.0205
# Epoch 2/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0347 - val_loss: 0.0083
# Epoch 3/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0252 - val_loss: 0.0040
# Epoch 4/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0192 - val_loss: 0.0059
# Epoch 5/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0165 - val_loss: 0.0086
# Epoch 6/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0142 - val_loss: 0.0059
# Epoch 7/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0126 - val_loss: 0.0030
# Epoch 8/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0114 - val_loss: 0.0036
# Epoch 9/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0102 - val_loss: 0.0049
# Epoch 10/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0092 - val_loss: 0.0027
# Epoch 11/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0082 - val_loss: 0.0039
# Epoch 12/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 13/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0071 - val_loss: 0.0055
# Epoch 14/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 15/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 16/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 17/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 18/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0053 - val_loss: 0.0029
# Epoch 19/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 20/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0050 - val_loss: 0.0025
# Epoch 21/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0048 - val_loss: 0.0025
# Epoch 22/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 23/500
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 24/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 25/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 26/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 27/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 28/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 29/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 30/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 31/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 32/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 33/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 34/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 35/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 36/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 37/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 38/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 39/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 40/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 41/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 42/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 43/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 44/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 45/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 46/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 47/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 48/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 49/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 50/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 51/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 52/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 53/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 54/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 55/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 56/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 57/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 58/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 59/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 60/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 61/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 62/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 63/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 64/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 65/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 66/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 67/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 68/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 69/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 70/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 71/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 72/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 73/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 74/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 75/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 76/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 77/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 78/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 79/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 80/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 81/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 82/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 83/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 84/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 85/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 86/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 87/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 88/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 89/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 90/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 91/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 92/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 93/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 94/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 95/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 96/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 97/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 98/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 99/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 100/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 101/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 102/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 103/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 104/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 105/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 106/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 107/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 108/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 109/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 110/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 111/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 112/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 113/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 114/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 115/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 116/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 117/500
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 118/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 119/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 120/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 121/500
# 40/40 [==============================] - 2s 37ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 122/500
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 123/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 124/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 125/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 126/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 127/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 128/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 129/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 130/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 131/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 132/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 133/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 134/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 135/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 136/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 137/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 138/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 139/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 140/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 141/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 142/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 143/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 144/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 145/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 146/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 147/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 148/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 149/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 150/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 151/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 152/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 153/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 154/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 155/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 156/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 157/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 158/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 159/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 160/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 161/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 162/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 163/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 164/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 165/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 166/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 167/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 168/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 169/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 170/500
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 171/500
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 172/500
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 173/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 174/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 175/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 176/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 177/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 178/500
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 179/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 180/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 181/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 182/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 183/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 184/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 185/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 186/500
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 187/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 188/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 189/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 190/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 191/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 192/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 193/500
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 194/500
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 195/500
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 196/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 197/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 198/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 199/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 200/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 201/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 202/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 203/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 204/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 205/500
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 206/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 207/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 208/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 209/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 210/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 211/500
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 212/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 213/500
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 214/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 215/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 216/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 217/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 218/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 219/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 220/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 221/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 222/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 223/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 224/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 225/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 226/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 227/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 228/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 229/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 230/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 231/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 232/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 233/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 234/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 235/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 236/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 237/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 238/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 239/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 240/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 241/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 242/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 243/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 244/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 245/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 246/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 247/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 248/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 249/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 250/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 251/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 252/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 253/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 254/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 255/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 256/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 257/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 258/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 259/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 260/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 261/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 262/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 263/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 264/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 265/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 266/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 267/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 268/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 269/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 270/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 271/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 272/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 273/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 274/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 275/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 276/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 277/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 278/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 279/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 280/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 281/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 282/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 283/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 284/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 285/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 286/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 287/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 288/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 289/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 290/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 291/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 292/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 293/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 294/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 295/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 296/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 297/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 298/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 299/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 300/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 301/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 302/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 303/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 304/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 305/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 306/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 307/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 308/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 309/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 310/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 311/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 312/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 313/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 314/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 315/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 316/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 317/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 318/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 319/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 320/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 321/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 322/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 323/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 324/500
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 325/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 326/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 327/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 328/500
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 329/500
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 330/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 331/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 332/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 333/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 334/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 335/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 336/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 337/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 338/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 339/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 340/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 341/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 342/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 343/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 344/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 345/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 346/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 347/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 348/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 349/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 350/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 351/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 352/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 353/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 354/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 355/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 356/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 357/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 358/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 359/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 360/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 361/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 362/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 363/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 364/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 365/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 366/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 367/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 368/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 369/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 370/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 371/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 372/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 373/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 374/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 375/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 376/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 377/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 378/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 379/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 380/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 381/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 382/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 383/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 384/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 385/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 386/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 387/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 388/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 389/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 390/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 391/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 392/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 393/500
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 394/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 395/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 396/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 397/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 398/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 399/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 400/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 401/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 402/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 403/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 404/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 405/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 406/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0043
# Epoch 407/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 408/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 409/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 410/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 411/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 412/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 413/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 414/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 415/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 416/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 417/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 418/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 419/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 420/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 421/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 422/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 423/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 424/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 425/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 426/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 427/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 428/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 429/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 430/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 431/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 432/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 433/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 434/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 435/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 436/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 437/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 438/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 439/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 440/500
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 441/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 442/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 443/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 444/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 445/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 446/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 447/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 448/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 449/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 450/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 451/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 452/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 453/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 454/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 455/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 456/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 457/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 458/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 459/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 460/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 461/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 462/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 463/500
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 464/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 465/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 466/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 467/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 468/500
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 469/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 470/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 471/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 472/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 473/500
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 474/500
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 475/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 476/500
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 477/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 478/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 479/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 480/500
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 481/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 482/500
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 483/500
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 484/500
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 485/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 486/500
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 487/500
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 488/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 489/500
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 490/500
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 491/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 492/500
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 493/500
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 494/500
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 495/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 496/500
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 497/500
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 498/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 499/500
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 500/500
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0016 - val_loss: 0.0020

# %%
aux.plot_train_history(multi_step_history,
                       'Función de pérdida\n(Modelo a tres pasos adelante)')

# %%
y_predictions = multi_step_model.predict(x_val_multi)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
y_pred_orig = min_max_scaler.inverse_transform(np.repeat(y_predictions, 6, axis = 1))[:,5]
y_true_orig = min_max_scaler.inverse_transform(np.repeat(np.resize(y_val_multi,(len(y_val_multi),1)),6, axis = 1))[:,5]

# %%
def RMS(actual, predicted):
    return np.sqrt(np.mean(np.power(predicted-actual,2)))

print("RMS - Medida del error de predicción\n------------------------------------")
print("Escala original:", round(RMS(y_pred_orig, y_true_orig),3))
print("Sin revertir la escala:", round(RMS(y_predictions, y_val_multi),3))
# Out:
# RMS - Medida del error de predicción
# ------------------------------------
# Escala original: 43.807
# Sin revertir la escala: 0.104

# %%
plt.plot(y_true_orig, label = 'Valor verdadero')
plt.plot(y_pred_orig, label = 'Predicción')
plt.legend()

# %%
for x, y in val_data_multi.take(3):
    plot = aux.show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    multi_step_model.predict(x)[0]], 12,
                   'Predicciones de un paso')
    plot.show()
# Out:
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step

# %% [markdown]
# ## Intervalos de predicción

# %%
from sklearn.metrics import mean_absolute_error
def fit_model(x_train_multi, y_train_multi):
    model = keras.Sequential()
    model.add(layers.SimpleRNN(30,
                               activation = 'tanh',
                               use_bias=True,
                               input_shape= x_train_multi.shape[-2:]
                              ))
    model.add(layers.Dropout(rate=0.2)) 
    model.add(layers.Dense(1))
    model.compile(loss='mean_squared_error', optimizer = 'adam')
    model.fit(train_data_multi,
              epochs = 100,
              steps_per_epoch = 40,
              validation_data = val_data_multi,
              validation_steps = 50,
              verbose=0)
    return model

# %%
def fit_ensemble(n_members, x_train_multi, x_val_multi, y_train_multi, y_val_multi):
    ensemble = list()
    for i in range(n_members):
        # Definir y entrenar el modelo en el conjunto de entrenamiento
        model = fit_model(x_train_multi, y_train_multi)
        # Evaluar el modelo en el conjunto de testeo
        yhat = model.predict(x_val_multi, verbose=0)
        mae = mean_absolute_error(y_val_multi, yhat)
        print('>%d, MAE: %.3f' % (i+1, mae))
        # Guardar el modelo
        ensemble.append(model)
    return ensemble

# %%
def predict_with_pred_int(ensemble, X):
    # Hacer prediccciones
    yhat = [model.predict(X, verbose=0) for model in ensemble]
    yhat = np.asarray(yhat)
    # Calcular un intervalo del 95% (Asumiendo que es un proceso gaussiano)
    interval = 1.96 * yhat.std()
    lower, upper = yhat.mean() - interval, yhat.mean() + interval
    return lower, yhat.mean(), upper

# %%
n_members = 30
ensemble = fit_ensemble(n_members, x_train_multi, x_val_multi, y_train_multi, y_val_multi)
# Out:
# >1, MAE: 0.041
# >2, MAE: 0.034
# >3, MAE: 0.038
# >4, MAE: 0.036
# >5, MAE: 0.041
# >6, MAE: 0.049
# >7, MAE: 0.042
# >8, MAE: 0.046
# >9, MAE: 0.036
# >10, MAE: 0.033
# >11, MAE: 0.039
# >12, MAE: 0.043
# >13, MAE: 0.034
# >14, MAE: 0.036
# >15, MAE: 0.044
# >16, MAE: 0.046
# >17, MAE: 0.047
# >18, MAE: 0.037
# >19, MAE: 0.033
# >20, MAE: 0.036
# >21, MAE: 0.034
# >22, MAE: 0.034
# >23, MAE: 0.041
# >24, MAE: 0.047
# >25, MAE: 0.032
# >26, MAE: 0.039
# >27, MAE: 0.039
# >28, MAE: 0.038
# >29, MAE: 0.036
# >30, MAE: 0.042

# %%
newX = np.asarray([x_val_multi[2, :]])
lower, mean, upper = predict_with_pred_int(ensemble, newX)
print('Predicción puntual: %.3f' % mean)
print('95%% Intervalo de predicción: [%.3f, %.3f]' % (lower, upper))
print('Valor verdadero: %.3f' % y_val_multi[2])
print('Valor predicho: %.3f' % y_predictions[2])
# Out:
# Predicción puntual: 0.719
# 95% Intervalo de predicción: [0.697, 0.741]
# Valor verdadero: 0.744
# Valor predicho: 0.754

# %%
lower_list, mean_list, upper_list = [], [], []
for i in range(0,y_val_multi.shape[0]):
    newX = np.asarray([x_val_multi[i, :]])
    lower, mean, upper = predict_with_pred_int(ensemble, newX)
    lower_list.append(lower)
    mean_list.append(mean)
    upper_list.append(upper)

# %%
plt.plot(y_val_multi, label = 'Valor verdadero')
plt.plot(y_predictions, label = 'Predicción')
plt.plot(lower_list, label = 'Límite inferior')
plt.plot(upper_list, label = 'Límite superior')
plt.fill_between(range(0,124), lower_list, upper_list, alpha = 0.3)
plt.legend()

# %%
cobertura_pred = [True if (lower_list[i] <=y_predictions[i] <= upper_list[i]) else False for i in range(0, len(y_predictions))]
cobertura_orig = [True if (lower_list[i] <=y_val_multi[i] <= upper_list[i]) else False for i in range(0, len(y_predictions))]
print("Porcentaje de las predicciones que caen dentro del intervalo:", round(sum(cobertura_pred)*100/len(cobertura_pred),2), "%")
print("Porcentaje de las predicciones que caen dentro del intervalo:", round(sum(cobertura_orig)*100/len(cobertura_orig),2), "%")
# Out:
# Porcentaje de las predicciones que caen dentro del intervalo: 81.45 %
# Porcentaje de las predicciones que caen dentro del intervalo: 33.06 %
