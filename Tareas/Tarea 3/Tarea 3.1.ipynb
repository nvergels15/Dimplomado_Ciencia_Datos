# %% [markdown]
# <table width='100%'>
# <tr>
# <td style='background-color:white'>
#     <p align="left">
#     Departamento de estadística<br>
#         <b>Inteligencia Artificial</b><br>
#     Semestre 2023-I
#     </p>
# </td>
#     <td style='background-color:white'>
#         <p align="right">
#         <img src="logo.jpg" width="200">
#     </td>
# </tr>
# </table>
#
# <br>
# <center>
#     <h1>Tarea 3: Programación orientada a objetos</h1>
#     <h2>Primera clase</h2>
# </center>
# <br>
#
# Consiga el conjunto de datos iris.csv. En el repositorio de Aprendizaje Profundo encuentra alguna versión.
# * Escriba una clase iterable que tenga la siguiente funcionalidad
# * Al instanciar un objeto, lee el archivo de datos y lo coloca en un dataframe interno en la clase.
# * Cada vez que se le pidan datos, debe regresar los dos siguientes datos.
# * Entregue un error si los datos se han agotado

# %% [markdown]
# Primero vamos a definir la clase iterable.

# %%
class Leer_Datos: 
    
    # Definir constructor
    def __init__(self, path, col_names):
        self.df = pd.read_csv(path, names = col_names)
        self.fila_actual = 0
        self.total_filas = len(self.df)
        
    def __iter__(self):
        self.fila_actual = 0
        return self
    
    def __next__(self):
        if self.fila_actual < self.total_filas - 2:
            output = self.df.iloc[self.fila_actual:self.fila_actual + 2]
            self.fila_actual += 2
            
            return output
        
        print("--------------------------------------------\nFin: Se ha impreso el 100% del dataframe.")
        self.fila_actual = 0
        raise StopIteration
        
    def pedirDatos(self):
        if self.fila_actual < self.total_filas - 2:
            output = self.df.iloc[self.fila_actual:self.fila_actual + 2]
            self.fila_actual += 2
            
            return output
        self.fila_actual = 0
        raise IndexError("¡ERROR! Se han acabado los datos")

# %% [markdown]
# Luego, instanciamos un objeto usando los datos de iris.

# %%
import pandas as pd

# Link a los datos
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# Nombres de las columnas
columnas = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class']

# Instanciar objeto
datos = Leer_Datos(path = csv_url, col_names = columnas)

# %% [markdown]
# Probamos la función <code>pedirDatos()</code>.

# %%
datos.pedirDatos()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %% [markdown]
# Observe que si ejecutamos la función 100 veces, se acabarán los datos y mostrará un error.

# %%
for i in range(100):
    datos.pedirDatos()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29704/1228646975.py in <module>
#       1 for i in range(100):
# ----> 2     datos.pedirDatos()
#
# ~\AppData\Local\Temp/ipykernel_29704/2517425493.py in pedirDatos(self)
#      29             return output
#      30         self.fila_actual = 0
# ---> 31         raise IndexError("¡ERROR! Se han acabado los datos")
#
# IndexError: ¡ERROR! Se han acabado los datos

# %% [markdown]
# Observe que la clase es iterable.

# %%
# Pedir datos
for i in datos:
    print(i)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# ...
